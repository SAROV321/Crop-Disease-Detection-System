# %%
pip install tensorflow pandas matplotlib pillow scikit-learn notebook jupyter
# Out:
# Requirement already satisfied: tensorflow in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (2.21.0)
# Requirement already satisfied: pandas in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (2.3.3)
# Requirement already satisfied: matplotlib in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (3.10.9)
# Requirement already satisfied: pillow in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (12.2.0)
# Requirement already satisfied: scikit-learn in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (1.7.2)
# Requirement already satisfied: notebook in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (7.5.6)
# Requirement already satisfied: jupyter in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (1.1.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\sarov\appdata\roaming\python\python310\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: keras>=3.12.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.12.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.2.6)
# Requirement already satisfied: setuptools in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (7.35.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.34.2)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\sarov\appdata\roaming\python\python310\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.81.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: packaging in c:\users\sarov\appdata\roaming\python\python310\site-packages (from tensorflow) (26.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sarov\appdata\roaming\python\python310\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: jupyterlab<4.6,>=4.5.7 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from notebook) (4.5.7)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\sarov\appdata\roaming\python\python310\site-packages (from notebook) (6.5.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from notebook) (2.18.2)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from notebook) (0.2.4)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from notebook) (2.28.0)
# Requirement already satisfied: jupyter-console in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: ipykernel in c:\users\sarov\appdata\roaming\python\python310\site-packages (from jupyter) (7.2.0)
# Requirement already satisfied: ipywidgets in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jupyter) (8.1.8)
# Requirement already satisfied: nbconvert in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jupyter) (7.17.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (25.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.1.6)
# Requirement already satisfied: traitlets>=5.6.0 in c:\users\sarov\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.15.0)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.9.0)
# Requirement already satisfied: overrides>=5.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.7.0)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.10.4)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.18.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\sarov\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.9.1)
# Requirement already satisfied: pyzmq>=24 in c:\users\sarov\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook) (27.1.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.5.4)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (4.13.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\sarov\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook) (8.8.0)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.0.3)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.12.1)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.25.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (2.1.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab<4.6,>=4.5.7->notebook) (2.3.1)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab<4.6,>=4.5.7->notebook) (2.3.0)
# Requirement already satisfied: tomli>=1.2.2 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab<4.6,>=4.5.7->notebook) (2.4.1)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab<4.6,>=4.5.7->notebook) (0.28.1)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\sarov\appdata\roaming\python\python310\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\sarov\appdata\roaming\python\python310\site-packages (from ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\sarov\appdata\roaming\python\python310\site-packages (from ipykernel->jupyter) (8.39.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\sarov\appdata\roaming\python\python310\site-packages (from ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\sarov\appdata\roaming\python\python310\site-packages (from ipykernel->jupyter) (1.8.20)
# Requirement already satisfied: psutil>=5.7 in c:\users\sarov\appdata\roaming\python\python310\site-packages (from ipykernel->jupyter) (7.2.2)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (4.26.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (0.14.0)
# Requirement already satisfied: babel>=2.10 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (2.18.0)
# Requirement already satisfied: namex in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.12.0->tensorflow) (0.19.1)
# Requirement already satisfied: rich in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.12.0->tensorflow) (15.0.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter) (3.0.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter) (4.14.3)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\sarov\appdata\roaming\python\python310\site-packages (from nbconvert->jupyter) (2.20.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: defusedxml in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter) (0.10.4)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter) (3.2.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: bleach[css]!=5.0.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter) (6.3.0)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.5.20)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.16)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets->jupyter) (3.0.16)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets->jupyter) (4.0.15)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\sarov\appdata\roaming\python\python310\site-packages (from jupyter-console->jupyter) (3.0.52)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\sarov\appdata\roaming\python\python310\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (25.1.0)
# Requirement already satisfied: webencodings in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: httpcore==1.* in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.7->notebook) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.7->notebook) (0.16.0)
# Requirement already satisfied: stack_data in c:\users\sarov\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.3)
# Requirement already satisfied: decorator in c:\users\sarov\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.3.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\sarov\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.20.0)
# Requirement already satisfied: colorama in c:\users\sarov\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.6)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (0.37.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (0.30.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (26.1.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\sarov\appdata\roaming\python\python310\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (4.9.6)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (6.0.3)
# Requirement already satisfied: rfc3339-validator in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (4.1.0)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook) (2.21.2)
# Requirement already satisfied: wcwidth in c:\users\sarov\appdata\roaming\python\python310\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.7.0)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.8.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (4.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in c:\users\sarov\appdata\roaming\python\python310\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.7)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (1.1.0)
# Requirement already satisfied: fqdn in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (1.5.1)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (3.1.1)
# Requirement already satisfied: uri-template in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (25.10.0)
# Requirement already satisfied: isoduration in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (20.11.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (2.0.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\sarov\appdata\roaming\python\python310\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\sarov\appdata\roaming\python\python310\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\sarov\appdata\roaming\python\python310\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: pycparser in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (3.0)
# Requirement already satisfied: lark>=1.2.2 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\sarov\appdata\local\programs\python\python310\lib\site-packages (from isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (1.4.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

# %%
dataset_path = r"C:\Users\sarov\.cache\kagglehub\datasets\emmarex\plantdisease\versions\1\PlantVillage"

# %%
classes = os.listdir(dataset_path)

print("Number of Classes:", len(classes))
print("\nClass Names:")

for cls in classes:
    print(cls)
# Out:
# Number of Classes: 16
#
# Class Names:
# Pepper__bell___Bacterial_spot
# Pepper__bell___healthy
# PlantVillage
# Potato___Early_blight
# Potato___healthy
# Potato___Late_blight
# Tomato_Bacterial_spot
# Tomato_Early_blight
# Tomato_healthy
# Tomato_Late_blight
# Tomato_Leaf_Mold
# Tomato_Septoria_leaf_spot
# Tomato_Spider_mites_Two_spotted_spider_mite
# Tomato__Target_Spot
# Tomato__Tomato_mosaic_virus
# Tomato__Tomato_YellowLeaf__Curl_Virus

# %%
class_df = pd.DataFrame(classes, columns=["Disease Class"])

class_df
# Out:
#                                   Disease Class
# 0                 Pepper__bell___Bacterial_spot
# 1                        Pepper__bell___healthy
# 2                                  PlantVillage
# 3                         Potato___Early_blight
# 4                              Potato___healthy
# 5                          Potato___Late_blight
# 6                         Tomato_Bacterial_spot
# 7                           Tomato_Early_blight
# 8                                Tomato_healthy
# 9                            Tomato_Late_blight
# 10                             Tomato_Leaf_Mold
# 11                    Tomato_Septoria_leaf_spot
# 12  Tomato_Spider_mites_Two_spotted_spider_mite
# 13                          Tomato__Target_Spot
# 14                  Tomato__Tomato_mosaic_virus
# 15        Tomato__Tomato_YellowLeaf__Curl_Virus

# %%
class_df.to_csv("Outputs/class_names.csv", index=False)

print("Class names saved successfully.")
# Out:
# Class names saved successfully.

# %%
import os

image_count = {}

for cls in classes:
    class_path = os.path.join(dataset_path, cls)

    if os.path.isdir(class_path):
        image_count[cls] = len(os.listdir(class_path))

image_count
# Out:
# {'Pepper__bell___Bacterial_spot': 997,
#  'Pepper__bell___healthy': 1478,
#  'PlantVillage': 15,
#  'Potato___Early_blight': 1000,
#  'Potato___healthy': 152,
#  'Potato___Late_blight': 1000,
#  'Tomato_Bacterial_spot': 2127,
#  'Tomato_Early_blight': 1000,
#  'Tomato_healthy': 1591,
#  'Tomato_Late_blight': 1909,
#  'Tomato_Leaf_Mold': 952,
#  'Tomato_Septoria_leaf_spot': 1771,
#  'Tomato_Spider_mites_Two_spotted_spider_mite': 1676,
#  'Tomato__Target_Spot': 1404,
#  'Tomato__Tomato_mosaic_virus': 373,
#  'Tomato__Tomato_YellowLeaf__Curl_Virus': 3209}

# %%
count_df = pd.DataFrame(
    image_count.items(),
    columns=["Disease Class", "Number of Images"]
)

count_df
# Out:
#                                   Disease Class  Number of Images
# 0                 Pepper__bell___Bacterial_spot               997
# 1                        Pepper__bell___healthy              1478
# 2                                  PlantVillage                15
# 3                         Potato___Early_blight              1000
# 4                              Potato___healthy               152
# 5                          Potato___Late_blight              1000
# 6                         Tomato_Bacterial_spot              2127
# 7                           Tomato_Early_blight              1000
# 8                                Tomato_healthy              1591
# 9                            Tomato_Late_blight              1909
# 10                             Tomato_Leaf_Mold               952
# 11                    Tomato_Septoria_leaf_spot              1771
# 12  Tomato_Spider_mites_Two_spotted_spider_mite              1676
# 13                          Tomato__Target_Spot              1404
# 14                  Tomato__Tomato_mosaic_virus               373
# 15        Tomato__Tomato_YellowLeaf__Curl_Virus              3209

# %%
count_df.to_csv("Outputs/image_count.csv", index=False)

print("Image count table saved successfully.")
# Out:
# Image count table saved successfully.

# %%
total_images = count_df["Number of Images"].sum()

print("Total Classes :", len(count_df))
print("Total Images  :", total_images)
# Out:
# Total Classes : 16
# Total Images  : 20654

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))

plt.bar(count_df["Disease Class"], count_df["Number of Images"])

plt.title("Number of Images in Each Disease Class")
plt.xlabel("Disease Class")
plt.ylabel("Number of Images")

plt.xticks(rotation=90)

plt.tight_layout()

plt.show()

# %%
largest = count_df.loc[count_df["Number of Images"].idxmax()]
smallest = count_df.loc[count_df["Number of Images"].idxmin()]

print("Largest Class")
print(largest)

print("\nSmallest Class")
print(smallest)
# Out:
# Largest Class
# Disease Class       Tomato__Tomato_YellowLeaf__Curl_Virus
# Number of Images                                     3209
# Name: 15, dtype: object
#
# Smallest Class
# Disease Class       PlantVillage
# Number of Images              15
# Name: 2, dtype: object

# %%
plt.figure(figsize=(12,6))

plt.bar(count_df["Disease Class"], count_df["Number of Images"])

plt.xticks(rotation=90)

plt.tight_layout()

plt.savefig("Outputs/class_distribution.png")

plt.show()

# %%
import os
import random
from PIL import Image
import matplotlib.pyplot as plt

dataset_path = r"C:\Users\sarov\.cache\kagglehub\datasets\emmarex\plantdisease\versions\1\PlantVillage"

plt.figure(figsize=(15,10))

classes = os.listdir(dataset_path)

for i in range(15):

    class_name = random.choice(classes)
    class_path = os.path.join(dataset_path, class_name)

    image_name = random.choice(os.listdir(class_path))
    image_path = os.path.join(class_path, image_name)

    img = Image.open(image_path)

    plt.subplot(3,5,i+1)
    plt.imshow(img)
    plt.title(class_name)
    plt.axis("off")

plt.tight_layout()
plt.show()
